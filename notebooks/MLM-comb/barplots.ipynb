# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np
import os

# %%
csv_paths = [os.path.join('../', x, 'ft_results_all_seeds.csv') for x in ["5M-MLM", "10M-MLM", "77M-MLM"]]

# %%
csv_paths
# Out:
# ['../5M-MLM/ft_results_all_seeds.csv',
#  '../10M-MLM/ft_results_all_seeds.csv',
#  '../77M-MLM/ft_results_all_seeds.csv']

# %%
dfs = [pd.read_csv(p) for p in csv_paths]

# %%
# only pick run_names from 77
run_names_to_use = dfs[-1].run_name.unique()

# %%
mlm_df = pd.concat(dfs, axis=0).reset_index(drop=True).sort_values(by='min_eval_loss')
mlm_df = mlm_df[mlm_df.run_name.isin(run_names_to_use)]

# %%
mlm_df.to_csv('mlm_results_all_seeds.csv', index=False)

# %%
run_names_to_use
# Out:
# array(['run_19', 'run_11', 'run_39', 'run_38', 'run_45'], dtype=object)

# %%
mlm_df
# Out:
#     run_name  min_eval_loss  hidden_size  attention_probs_dropout_prob  \
# 104   run_45       0.136374          384                         0.109
# 102   run_45       0.136374          384                         0.109
# 101   run_45       0.136374          384                         0.109
# 100   run_45       0.136374          384                         0.109
# 103   run_45       0.136374          384                         0.109
# ..       ...            ...          ...                           ...
# 4     run_11       0.695174          112                         0.118
# 3     run_11       0.695174          112                         0.118
# 2     run_11       0.695174          112                         0.118
# 1     run_11       0.695174          112                         0.118
# 0     run_11       0.695174          112                         0.118
#
#      hidden_dropout_prob  intermediate_size  num_attention_heads  \
# 104                0.144                464                   12
# 102                0.144                464                   12
# 101                0.144                464                   12
# 100                0.144                464                   12
# 103                0.144                464                   12
# ..                   ...                ...                  ...
# 4                  0.183               4844                    8
# 3                  0.183               4844                    8
# 2                  0.183               4844                    8
# 1                  0.183               4844                    8
# 0                  0.183               4844                    8
#
#      num_hidden_layers  learning_rate pretraining_task  ...  \
# 104                  3       0.000141          77M-MLM  ...
# 102                  3       0.000141          77M-MLM  ...
# 101                  3       0.000141          77M-MLM  ...
# 100                  3       0.000141          77M-MLM  ...
# 103                  3       0.000141          77M-MLM  ...
# ..                 ...            ...              ...  ...
# 4                    5       0.000002           5M-MLM  ...
# 3                    5       0.000002           5M-MLM  ...
# 2                    5       0.000002           5M-MLM  ...
# 1                    5       0.000002           5M-MLM  ...
# 0                    5       0.000002           5M-MLM  ...
#
#      delaney_test_pearsonr  delaney_test_rmse  lipo_valid_pearsonr  \
# 104               0.875762           0.504182             0.689844
# 102               0.870452           0.513691             0.740373
# 101               0.870767           0.513124             0.718443
# 100               0.874943           0.506494             0.700273
# 103               0.871235           0.511006             0.687219
# ..                     ...                ...                  ...
# 4                 0.725576           0.752333             0.581188
# 3                 0.682729           0.804081             0.610482
# 2                 0.748754           0.719029             0.589683
# 1                 0.728683           0.756207             0.602142
# 0                 0.719212           0.743731             0.634181
#
#      lipo_valid_rmse  lipo_test_pearsonr  lipo_test_rmse  \
# 104         0.758536            0.634108        0.739025
# 102         0.711280            0.693528        0.700368
# 101         0.734897            0.675877        0.713733
# 100         0.742192            0.647553        0.722768
# 103         0.751247            0.636140        0.726191
# ..               ...                 ...             ...
# 4           0.819264            0.466096        0.815085
# 3           0.796291            0.521493        0.790394
# 2           0.813896            0.511526        0.792144
# 1           0.803671            0.471359        0.820449
# 0           0.777338            0.530516        0.790485
#
#      tox21_valid_roc_auc_score  tox21_valid_average_precision_score  \
# 104                   0.701527                             0.412342
# 102                   0.704744                             0.413110
# 101                   0.707962                             0.413216
# 100                   0.704272                             0.409440
# 103                   0.706889                             0.418142
# ..                         ...                                  ...
# 4                     0.734171                             0.351607
# 3                     0.735415                             0.358375
# 2                     0.732756                             0.378155
# 1                     0.759737                             0.406584
# 0                     0.765142                             0.402088
#
#      tox21_test_roc_auc_score  tox21_test_average_precision_score
# 104                  0.732032                            0.328458
# 102                  0.736484                            0.332703
# 101                  0.737756                            0.335231
# 100                  0.732374                            0.329506
# 103                  0.738539                            0.331947
# ..                        ...                                 ...
# 4                    0.747150                            0.260902
# 3                    0.756299                            0.250198
# 2                    0.753364                            0.265832
# 1                    0.737022                            0.278703
# 0                    0.725084                            0.264528
#
# [75 rows x 42 columns]

# %%
mlm_df.filter(like='roc')
# Out:
#      bace_classification_valid_roc_auc_score  \
# 104                                 0.613539
# 102                                 0.613539
# 101                                 0.613539
# 100                                 0.613539
# 103                                 0.613539
# ..                                       ...
# 4                                   0.611763
# 3                                   0.651741
# 2                                   0.622601
# 1                                   0.639303
# 0                                   0.617626
#
#      bace_classification_test_roc_auc_score  bbbp_valid_roc_auc_score  \
# 104                                0.560145                  0.956425
# 102                                0.560326                  0.958269
# 101                                0.560145                  0.958754
# 100                                0.560145                  0.957298
# 103                                0.560145                  0.958172
# ..                                      ...                       ...
# 4                                  0.747101                  0.478406
# 3                                  0.752174                  0.478843
# 2                                  0.754348                  0.478940
# 1                                  0.763406                  0.478552
# 0                                  0.742210                  0.478746
#
#      bbbp_test_roc_auc_score  clintox_valid_roc_auc_score  \
# 104                 0.736776                     0.545775
# 102                 0.735331                     0.537559
# 101                 0.734946                     0.529343
# 100                 0.741979                     0.654930
# 103                 0.739570                     0.539906
# ..                       ...                          ...
# 4                   0.479333                     0.782864
# 3                   0.479526                     0.780516
# 2                   0.479526                     0.784038
# 1                   0.479526                     0.803991
# 0                   0.479430                     0.769953
#
#      clintox_test_roc_auc_score  tox21_valid_roc_auc_score  \
# 104                    0.631095                   0.701527
# 102                    0.631894                   0.704744
# 101                    0.634293                   0.707962
# 100                    0.630296                   0.704272
# 103                    0.635891                   0.706889
# ..                          ...                        ...
# 4                      0.509992                   0.734171
# 3                      0.439249                   0.735415
# 2                      0.469624                   0.732756
# 1                      0.488409                   0.759737
# 0                      0.463229                   0.765142
#
#      tox21_test_roc_auc_score
# 104                  0.732032
# 102                  0.736484
# 101                  0.737756
# 100                  0.732374
# 103                  0.738539
# ..                        ...
# 4                    0.747150
# 3                    0.756299
# 2                    0.753364
# 1                    0.737022
# 0                    0.725084
#
# [75 rows x 8 columns]

# %%
mlm_df.sort_values(by='delaney_test_rmse').iloc[:15]
# Out:
#    run_name  min_eval_loss  hidden_size  attention_probs_dropout_prob  \
# 71   run_45       0.147017          384                         0.109
# 73   run_45       0.147017          384                         0.109
# 49   run_45       0.180579          384                         0.109
# 72   run_45       0.147017          384                         0.109
# 70   run_45       0.147017          384                         0.109
# 47   run_45       0.180579          384                         0.109
# 46   run_45       0.180579          384                         0.109
# 45   run_45       0.180579          384                         0.109
# 74   run_45       0.147017          384                         0.109
# 48   run_45       0.180579          384                         0.109
# 51   run_39       0.429169          209                         0.176
# 14   run_39       0.512588          209                         0.176
# 53   run_39       0.429169          209                         0.176
# 13   run_39       0.512588          209                         0.176
# 93   run_39       0.421750          209                         0.176
#
#     hidden_dropout_prob  intermediate_size  num_attention_heads  \
# 71                0.144                464                   12
# 73                0.144                464                   12
# 49                0.144                464                   12
# 72                0.144                464                   12
# 70                0.144                464                   12
# 47                0.144                464                   12
# 46                0.144                464                   12
# 45                0.144                464                   12
# 74                0.144                464                   12
# 48                0.144                464                   12
# 51                0.128               3968                   11
# 14                0.128               3968                   11
# 53                0.128               3968                   11
# 13                0.128               3968                   11
# 93                0.128               3968                   11
#
#     num_hidden_layers  learning_rate pretraining_task  ...  \
# 71                  3       0.000141          10M-MLM  ...
# 73                  3       0.000141          10M-MLM  ...
# 49                  3       0.000141           5M-MLM  ...
# 72                  3       0.000141          10M-MLM  ...
# 70                  3       0.000141          10M-MLM  ...
# 47                  3       0.000141           5M-MLM  ...
# 46                  3       0.000141           5M-MLM  ...
# 45                  3       0.000141           5M-MLM  ...
# 74                  3       0.000141          10M-MLM  ...
# 48                  3       0.000141           5M-MLM  ...
# 51                  3       0.000002          10M-MLM  ...
# 14                  3       0.000002           5M-MLM  ...
# 53                  3       0.000002          10M-MLM  ...
# 13                  3       0.000002           5M-MLM  ...
# 93                  3       0.000002          77M-MLM  ...
#
#     delaney_test_pearsonr  delaney_test_rmse  lipo_valid_pearsonr  \
# 71               0.909580           0.435431             0.740711
# 73               0.909832           0.435814             0.744456
# 49               0.907939           0.436468             0.692914
# 72               0.908232           0.436801             0.749266
# 70               0.905881           0.441218             0.744444
# 47               0.904657           0.444907             0.691360
# 46               0.903962           0.445557             0.704371
# 45               0.903643           0.448199             0.699509
# 74               0.901861           0.448837             0.720865
# 48               0.899897           0.454447             0.696657
# 51               0.893529           0.469569             0.599654
# 14               0.889632           0.469965             0.628462
# 53               0.888880           0.484284             0.586889
# 13               0.884140           0.489683             0.649833
# 93               0.879640           0.492666             0.604261
#
#     lipo_valid_rmse  lipo_test_pearsonr  lipo_test_rmse  \
# 71         0.735474            0.717953        0.696740
# 73         0.712699            0.712487        0.683005
# 49         0.761595            0.639233        0.726154
# 72         0.700821            0.733807        0.657533
# 70         0.705519            0.722884        0.665679
# 47         0.761331            0.638647        0.725254
# 46         0.751704            0.654923        0.716522
# 45         0.756578            0.648478        0.720996
# 74         0.734076            0.692787        0.692444
# 48         0.756309            0.645779        0.720473
# 51         0.806719            0.514140        0.788926
# 14         0.783936            0.552101        0.764687
# 53         0.815365            0.503509        0.800754
# 13         0.773937            0.575803        0.751013
# 93         0.802144            0.490747        0.821000
#
#     tox21_valid_roc_auc_score  tox21_valid_average_precision_score  \
# 71                   0.786676                             0.469447
# 73                   0.755920                             0.419479
# 49                   0.773121                             0.485079
# 72                   0.777239                             0.451759
# 70                   0.783717                             0.472981
# 47                   0.767201                             0.494616
# 46                   0.774794                             0.484873
# 45                   0.757593                             0.456008
# 74                   0.780285                             0.474502
# 48                   0.769432                             0.479895
# 51                   0.761625                             0.408209
# 14                   0.741721                             0.364954
# 53                   0.776381                             0.431358
# 13                   0.780885                             0.408048
# 93                   0.768703                             0.416913
#
#     tox21_test_roc_auc_score  tox21_test_average_precision_score
# 71                  0.732325                            0.357853
# 73                  0.734185                            0.352519
# 49                  0.762415                            0.347655
# 72                  0.745389                            0.366156
# 70                  0.740594                            0.352845
# 47                  0.766378                            0.338719
# 46                  0.772738                            0.343719
# 45                  0.753804                            0.355788
# 74                  0.748031                            0.358638
# 48                  0.761828                            0.338312
# 51                  0.771858                            0.277485
# 14                  0.724302                            0.325037
# 53                  0.738343                            0.287014
# 13                  0.769558                            0.313999
# 93                  0.741719                            0.324869
#
# [15 rows x 42 columns]

# %%
regr_tasks = ['delaney', 'bace_regression', 'clearance', 'lipo']
clf_tasks = ['bbbp', 'bace_classification', 'clintox', 'tox21']

# %%
# we only want a single representative model per task
best_run_names = []
tasks = ['5M-MLM', '10M-MLM', '77M-MLM']
for task in tasks:
    best_run_names.append(mlm_df[mlm_df.pretraining_task == task].sort_values(by='min_eval_loss').iloc[0].run_name)

# %%
best_run_names
# Out:
# ['run_45', 'run_45', 'run_45']

# %%
# just always use run 45?

# %%
df = mlm_df[mlm_df['run_name'] == "run_45"]

# %%
df
# Out:
#     run_name  min_eval_loss  hidden_size  attention_probs_dropout_prob  \
# 104   run_45       0.136374          384                         0.109
# 102   run_45       0.136374          384                         0.109
# 101   run_45       0.136374          384                         0.109
# 100   run_45       0.136374          384                         0.109
# 103   run_45       0.136374          384                         0.109
# 72    run_45       0.147017          384                         0.109
# 73    run_45       0.147017          384                         0.109
# 74    run_45       0.147017          384                         0.109
# 71    run_45       0.147017          384                         0.109
# 70    run_45       0.147017          384                         0.109
# 48    run_45       0.180579          384                         0.109
# 47    run_45       0.180579          384                         0.109
# 49    run_45       0.180579          384                         0.109
# 45    run_45       0.180579          384                         0.109
# 46    run_45       0.180579          384                         0.109
#
#      hidden_dropout_prob  intermediate_size  num_attention_heads  \
# 104                0.144                464                   12
# 102                0.144                464                   12
# 101                0.144                464                   12
# 100                0.144                464                   12
# 103                0.144                464                   12
# 72                 0.144                464                   12
# 73                 0.144                464                   12
# 74                 0.144                464                   12
# 71                 0.144                464                   12
# 70                 0.144                464                   12
# 48                 0.144                464                   12
# 47                 0.144                464                   12
# 49                 0.144                464                   12
# 45                 0.144                464                   12
# 46                 0.144                464                   12
#
#      num_hidden_layers  learning_rate pretraining_task  ...  \
# 104                  3       0.000141          77M-MLM  ...
# 102                  3       0.000141          77M-MLM  ...
# 101                  3       0.000141          77M-MLM  ...
# 100                  3       0.000141          77M-MLM  ...
# 103                  3       0.000141          77M-MLM  ...
# 72                   3       0.000141          10M-MLM  ...
# 73                   3       0.000141          10M-MLM  ...
# 74                   3       0.000141          10M-MLM  ...
# 71                   3       0.000141          10M-MLM  ...
# 70                   3       0.000141          10M-MLM  ...
# 48                   3       0.000141           5M-MLM  ...
# 47                   3       0.000141           5M-MLM  ...
# 49                   3       0.000141           5M-MLM  ...
# 45                   3       0.000141           5M-MLM  ...
# 46                   3       0.000141           5M-MLM  ...
#
#      delaney_test_pearsonr  delaney_test_rmse  lipo_valid_pearsonr  \
# 104               0.875762           0.504182             0.689844
# 102               0.870452           0.513691             0.740373
# 101               0.870767           0.513124             0.718443
# 100               0.874943           0.506494             0.700273
# 103               0.871235           0.511006             0.687219
# 72                0.908232           0.436801             0.749266
# 73                0.909832           0.435814             0.744456
# 74                0.901861           0.448837             0.720865
# 71                0.909580           0.435431             0.740711
# 70                0.905881           0.441218             0.744444
# 48                0.899897           0.454447             0.696657
# 47                0.904657           0.444907             0.691360
# 49                0.907939           0.436468             0.692914
# 45                0.903643           0.448199             0.699509
# 46                0.903962           0.445557             0.704371
#
#      lipo_valid_rmse  lipo_test_pearsonr  lipo_test_rmse  \
# 104         0.758536            0.634108        0.739025
# 102         0.711280            0.693528        0.700368
# 101         0.734897            0.675877        0.713733
# 100         0.742192            0.647553        0.722768
# 103         0.751247            0.636140        0.726191
# 72          0.700821            0.733807        0.657533
# 73          0.712699            0.712487        0.683005
# 74          0.734076            0.692787        0.692444
# 71          0.735474            0.717953        0.696740
# 70          0.705519            0.722884        0.665679
# 48          0.756309            0.645779        0.720473
# 47          0.761331            0.638647        0.725254
# 49          0.761595            0.639233        0.726154
# 45          0.756578            0.648478        0.720996
# 46          0.751704            0.654923        0.716522
#
#      tox21_valid_roc_auc_score  tox21_valid_average_precision_score  \
# 104                   0.701527                             0.412342
# 102                   0.704744                             0.413110
# 101                   0.707962                             0.413216
# 100                   0.704272                             0.409440
# 103                   0.706889                             0.418142
# 72                    0.777239                             0.451759
# 73                    0.755920                             0.419479
# 74                    0.780285                             0.474502
# 71                    0.786676                             0.469447
# 70                    0.783717                             0.472981
# 48                    0.769432                             0.479895
# 47                    0.767201                             0.494616
# 49                    0.773121                             0.485079
# 45                    0.757593                             0.456008
# 46                    0.774794                             0.484873
#
#      tox21_test_roc_auc_score  tox21_test_average_precision_score
# 104                  0.732032                            0.328458
# 102                  0.736484                            0.332703
# 101                  0.737756                            0.335231
# 100                  0.732374                            0.329506
# 103                  0.738539                            0.331947
# 72                   0.745389                            0.366156
# 73                   0.734185                            0.352519
# 74                   0.748031                            0.358638
# 71                   0.732325                            0.357853
# 70                   0.740594                            0.352845
# 48                   0.761828                            0.338312
# 47                   0.766378                            0.338719
# 49                   0.762415                            0.347655
# 45                   0.753804                            0.355788
# 46                   0.772738                            0.343719
#
# [15 rows x 42 columns]

# %%
sns.set_context('talk')
sns.set_style('white')
sns.set(rc={'figure.figsize': (10, 8)})

# %%
for regr_task in regr_tasks:
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    for i,metric_name in enumerate(["rmse", "pearsonr"]):
        sns.barplot(
            data=df,
            x='pretraining_task',
            y=f'{regr_task}_test_{metric_name}',
            ci='sd', capsize=0.2, errwidth=3, palette='Blues',
            order=tasks,
            ax=ax[i]
        )
        ax[i].set_xlabel('Pretraining Task')
        ax[i].set_ylabel(f"{' '.join(metric_name.split('_')).title()}")
        ax[i].set_title(f"{' '.join(regr_task.split('_')).title()}")
#     plt.savefig(f"./barplots/{regr_task}_barplot.png", dpi=200)

# %%
mm = {
    "roc_auc_score": "ROC AUC",
    "average_precision_score": "PR AUC",
}
for clf_task in clf_tasks:
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))
    for i,metric_name in enumerate(mm.keys()):
        sns.barplot(
            data=df,
            x='pretraining_task',
            y=f'{clf_task}_test_{metric_name}',
            ci='sd', capsize=0.2, errwidth=3, palette='Reds',
            order=tasks,
            ax=ax[i]
        )
        ax[i].set_xlabel('Pretraining Task')
        ax[i].set_ylabel(f"{mm[metric_name]}")
        ax[i].set_title(f"{' '.join(clf_task.split('_')).title()}")
#     plt.savefig(f"./barplots/{clf_task}_barplot.png", dpi=200)

# %%
mlm_df
# Out:
#     run_name  min_eval_loss  hidden_size  attention_probs_dropout_prob  \
# 104   run_45       0.136374          384                         0.109
# 102   run_45       0.136374          384                         0.109
# 101   run_45       0.136374          384                         0.109
# 100   run_45       0.136374          384                         0.109
# 103   run_45       0.136374          384                         0.109
# ..       ...            ...          ...                           ...
# 4     run_11       0.695174          112                         0.118
# 3     run_11       0.695174          112                         0.118
# 2     run_11       0.695174          112                         0.118
# 1     run_11       0.695174          112                         0.118
# 0     run_11       0.695174          112                         0.118
#
#      hidden_dropout_prob  intermediate_size  num_attention_heads  \
# 104                0.144                464                   12
# 102                0.144                464                   12
# 101                0.144                464                   12
# 100                0.144                464                   12
# 103                0.144                464                   12
# ..                   ...                ...                  ...
# 4                  0.183               4844                    8
# 3                  0.183               4844                    8
# 2                  0.183               4844                    8
# 1                  0.183               4844                    8
# 0                  0.183               4844                    8
#
#      num_hidden_layers  learning_rate pretraining_task  ...  \
# 104                  3       0.000141          77M-MLM  ...
# 102                  3       0.000141          77M-MLM  ...
# 101                  3       0.000141          77M-MLM  ...
# 100                  3       0.000141          77M-MLM  ...
# 103                  3       0.000141          77M-MLM  ...
# ..                 ...            ...              ...  ...
# 4                    5       0.000002           5M-MLM  ...
# 3                    5       0.000002           5M-MLM  ...
# 2                    5       0.000002           5M-MLM  ...
# 1                    5       0.000002           5M-MLM  ...
# 0                    5       0.000002           5M-MLM  ...
#
#      delaney_test_pearsonr  delaney_test_rmse  lipo_valid_pearsonr  \
# 104               0.875762           0.504182             0.689844
# 102               0.870452           0.513691             0.740373
# 101               0.870767           0.513124             0.718443
# 100               0.874943           0.506494             0.700273
# 103               0.871235           0.511006             0.687219
# ..                     ...                ...                  ...
# 4                 0.725576           0.752333             0.581188
# 3                 0.682729           0.804081             0.610482
# 2                 0.748754           0.719029             0.589683
# 1                 0.728683           0.756207             0.602142
# 0                 0.719212           0.743731             0.634181
#
#      lipo_valid_rmse  lipo_test_pearsonr  lipo_test_rmse  \
# 104         0.758536            0.634108        0.739025
# 102         0.711280            0.693528        0.700368
# 101         0.734897            0.675877        0.713733
# 100         0.742192            0.647553        0.722768
# 103         0.751247            0.636140        0.726191
# ..               ...                 ...             ...
# 4           0.819264            0.466096        0.815085
# 3           0.796291            0.521493        0.790394
# 2           0.813896            0.511526        0.792144
# 1           0.803671            0.471359        0.820449
# 0           0.777338            0.530516        0.790485
#
#      tox21_valid_roc_auc_score  tox21_valid_average_precision_score  \
# 104                   0.701527                             0.412342
# 102                   0.704744                             0.413110
# 101                   0.707962                             0.413216
# 100                   0.704272                             0.409440
# 103                   0.706889                             0.418142
# ..                         ...                                  ...
# 4                     0.734171                             0.351607
# 3                     0.735415                             0.358375
# 2                     0.732756                             0.378155
# 1                     0.759737                             0.406584
# 0                     0.765142                             0.402088
#
#      tox21_test_roc_auc_score  tox21_test_average_precision_score
# 104                  0.732032                            0.328458
# 102                  0.736484                            0.332703
# 101                  0.737756                            0.335231
# 100                  0.732374                            0.329506
# 103                  0.738539                            0.331947
# ..                        ...                                 ...
# 4                    0.747150                            0.260902
# 3                    0.756299                            0.250198
# 2                    0.753364                            0.265832
# 1                    0.737022                            0.278703
# 0                    0.725084                            0.264528
#
# [75 rows x 42 columns]

# %% [markdown]
# ### Try plotting all the runs

# %%
fig, axes = plt.subplots(len(regr_tasks), 2, figsize=(15, 6*len(regr_tasks)))
for r,regr_task in enumerate(regr_tasks):
    for i,metric_name in enumerate(["rmse", "pearsonr"]):
        sns.barplot(
            data=mlm_df,
            x='run_name',
            y=f'{regr_task}_test_{metric_name}',
            ci='sd', capsize=0.1, errwidth=2, palette='Blues',
#             order=tasks,
            ax=axes[r, i],
#             hue='run_name',
            hue='pretraining_task'
        )
        axes[r, i].legend(loc=2, bbox_to_anchor=(1,1))
#         axes[r, i].set_xlabel('Pretraining Task')
        axes[r, i].set_xlabel('Model Configuration')
        axes[r, i].set_ylabel(f"{' '.join(metric_name.split('_')).title()}")
        axes[r, i].set_title(f"{' '.join(regr_task.split('_')).title()}")
        plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1.0, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
# plt.savefig(f"./barplots/molnet_regr_all_runs_barplot.png", dpi=200)
plt.savefig(f"./barplots/molnet_regr_all_runs_barplot_2.png", dpi=200, bbox_inches='tight')

# %%
mm = {
    "roc_auc_score": "ROC AUC",
    "average_precision_score": "PR AUC",
}
fig, axes = plt.subplots(len(clf_tasks), 2, figsize=(15, 6*len(clf_tasks)))
for c,clf_task in enumerate(clf_tasks):
    for i,metric_name in enumerate(mm.keys()):
        sns.barplot(
            data=mlm_df,
            x='run_name',
            y=f'{clf_task}_test_{metric_name}',
            ci='sd', capsize=0.1, errwidth=2, palette='Reds',
#             order=tasks,
            ax=axes[c, i],
#             hue='run_name',
            hue='pretraining_task'
        )
        axes[c, i].legend(loc=2, bbox_to_anchor=(1,1))
#         axes[r, i].set_xlabel('Pretraining Task')
        axes[c, i].set_xlabel('Model Configuration')
        axes[c, i].set_ylabel(f"{mm[metric_name]}")
        axes[c, i].set_title(f"{' '.join(clf_task.split('_')).title()}")
        plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=1.0, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
# plt.savefig(f"./barplots/molnet_clf_all_runs_barplot.png", dpi=200)
plt.savefig(f"./barplots/molnet_clf_all_runs_barplot_2.png", dpi=200, bbox_inches='tight')
