# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np
import os

# %%
csv_paths = [os.path.join('../', x, 'ft_results_combined.csv') for x in ["5M-MTR", "10M-MTR", "77M-MTR"]]

# %%
csv_paths
# Out:
# ['../5M-MTR/ft_results_combined.csv',
#  '../10M-MTR/ft_results_combined.csv',
#  '../77M-MTR/ft_results_combined.csv']

# %%
dfs = [pd.read_csv(p) for p in csv_paths]

# %%
dfs[-1]
# Out:
#   run_name  min_eval_loss  hidden_size  attention_probs_dropout_prob  \
# 0    run_0       0.070153          264                         0.224
# 1   run_45       0.040794          384                         0.109
# 2   run_38       0.259809          126                         0.109
# 3    run_1       0.144309          407                         0.156
# 4   run_39       0.235581          209                         0.176
#
#    hidden_dropout_prob  intermediate_size  num_attention_heads  \
# 0                0.122               4888                    8
# 1                0.144                464                   12
# 2                0.279                456                    3
# 3                0.295               9044                   11
# 4                0.128               3968                   11
#
#    num_hidden_layers  learning_rate  per_device_train_batch_size  ...  \
# 0                  3       0.000396                           25  ...
# 1                  3       0.000141                           25  ...
# 2                  2       0.000021                           25  ...
# 3                  2       0.000005                           25  ...
# 4                  3       0.000002                           25  ...
#
#   lipo_test_pearsonr_std  lipo_test_rmse_std  tox21_valid_roc_auc_score_mean  \
# 0               0.008190            0.008356                        0.796362
# 1               0.001592            0.005084                        0.776999
# 2               0.010757            0.006533                        0.757841
# 3               0.007048            0.003801                        0.784034
# 4               0.021736            0.016044                        0.734626
#
#    tox21_valid_average_precision_score_mean  tox21_valid_roc_auc_score_std  \
# 0                                  0.475050                       0.008810
# 1                                  0.492551                       0.003705
# 2                                  0.446270                       0.001440
# 3                                  0.491201                       0.010371
# 4                                  0.446543                       0.009882
#
#    tox21_valid_average_precision_score_std  tox21_test_roc_auc_score_mean  \
# 0                                 0.007511                       0.752992
# 1                                 0.002459                       0.772504
# 2                                 0.002977                       0.819531
# 3                                 0.007209                       0.787348
# 4                                 0.022625                       0.798219
#
#    tox21_test_average_precision_score_mean  tox21_test_roc_auc_score_std  \
# 0                                 0.408613                      0.002091
# 1                                 0.438593                      0.003099
# 2                                 0.394257                      0.001457
# 3                                 0.403005                      0.008803
# 4                                 0.404890                      0.011476
#
#    tox21_test_average_precision_score_std
# 0                                0.006543
# 1                                0.003468
# 2                                0.001901
# 3                                0.009880
# 4                                0.031436
#
# [5 rows x 75 columns]

# %%
# only pick run_names from 77
run_names_to_use = dfs[-1].run_name.unique()

# %%
mtr_df = pd.concat(dfs, axis=0).reset_index(drop=True).sort_values(by='min_eval_loss')
mtr_df = mtr_df[mtr_df.run_name.isin(run_names_to_use)]

# %%
run_names_to_use
# Out:
# array(['run_0', 'run_45', 'run_38', 'run_1', 'run_39'], dtype=object)

# %%
clf_col_prefix = [
    "bace_classification",
    "bbbp",
    "clintox",
    "tox21",
]

regr_col_prefix = [
    "bace_regression",
    "clearance",
    "delaney",
    "lipo",
]

# %%
# regr_cols = [[r+"_rmse_mean", r+"_rmse_std"] for r in regr_col_prefix]
# regr_cols = [c for i in regr_cols for c in i]

res_dfs = []
task = "5M-MTR"

for i in regr_col_prefix:
    val_sort_col = i+"_test_rmse_mean"
    sub_df = mtr_df[mtr_df.pretraining_task == task].sort_values(by=val_sort_col)
    test_mean_col = i+"_test_rmse_mean"
    test_std_col = i+"_test_rmse_std"
    sub_df = sub_df[[test_mean_col, test_std_col]]
    res_dfs.append(sub_df.reset_index(drop=True))

# %%
res_df = pd.concat(res_dfs, axis=1)

# %%
res_df
# Out:
#    bace_regression_test_rmse_mean  bace_regression_test_rmse_std  \
# 0                        1.043666                       0.023895
# 1                        1.051768                       0.006089
# 2                        1.075564                       0.003071
# 3                        1.092537                       0.005550
# 4                        1.101416                       0.008106
#
#    clearance_test_rmse_mean  clearance_test_rmse_std  delaney_test_rmse_mean  \
# 0                  1.116011                 0.002129                0.405049
# 1                  1.117125                 0.003085                0.429835
# 2                  1.138627                 0.008223                0.451861
# 3                  1.147998                 0.004632                0.457114
# 4                  1.192413                 0.003933                0.508793
#
#    delaney_test_rmse_std  lipo_test_rmse_mean  lipo_test_rmse_std
# 0               0.002775             0.587170            0.005729
# 1               0.001781             0.656534            0.007907
# 2               0.006737             0.662727            0.004154
# 3               0.001186             0.670677            0.000540
# 4               0.017765             0.784134            0.001651

# %%
mtr_df.sort_values(by='bace_regression_valid_pearsonr_mean', ascending=False).filter(like='bace_regression')
# Out:
#     bace_regression_valid_pearsonr_mean  bace_regression_valid_rmse_mean  \
# 7                              0.224502                         0.502046
# 12                             0.220960                         0.490769
# 2                              0.205019                         0.495244
# 8                              0.189893                         0.524299
# 11                             0.178072                         0.515094
# 5                              0.174632                         0.537382
# 6                              0.173427                         0.519994
# 1                              0.172812                         0.563706
# 13                             0.170358                         0.523089
# 14                             0.169626                         0.507877
# 3                              0.161029                         0.603211
# 10                             0.158635                         0.515300
# 9                              0.136920                         0.486656
# 0                              0.133880                         0.550032
# 4                              0.113244                         0.493671
#
#     bace_regression_valid_pearsonr_std  bace_regression_valid_rmse_std  \
# 7                             0.004547                        0.000522
# 12                            0.001960                        0.002745
# 2                             0.000139                        0.000377
# 8                             0.001251                        0.001338
# 11                            0.000973                        0.000484
# 5                             0.003945                        0.001562
# 6                             0.013449                        0.002541
# 1                             0.006514                        0.001981
# 13                            0.002276                        0.001221
# 14                            0.012234                        0.001355
# 3                             0.001829                        0.000278
# 10                            0.002135                        0.000939
# 9                             0.004011                        0.001014
# 0                             0.002379                        0.001711
# 4                             0.000814                        0.001491
#
#     bace_regression_test_pearsonr_mean  bace_regression_test_rmse_mean  \
# 7                             0.743475                        1.101416
# 12                            0.767039                        1.009474
# 2                             0.715272                        1.087914
# 8                             0.796699                        1.051768
# 11                            0.709416                        1.128245
# 5                             0.776260                        1.075564
# 6                             0.778926                        1.043666
# 1                             0.803320                        1.076083
# 13                            0.817694                        1.009423
# 14                            0.792269                        1.037092
# 3                             0.787758                        1.243466
# 10                            0.747155                        1.067232
# 9                             0.715986                        1.092537
# 0                             0.753579                        1.100631
# 4                             0.730910                        1.094448
#
#     bace_regression_test_pearsonr_std  bace_regression_test_rmse_std
# 7                            0.002809                       0.008106
# 12                           0.003511                       0.006804
# 2                            0.000380                       0.001122
# 8                            0.000279                       0.006089
# 11                           0.001843                       0.002850
# 5                            0.001820                       0.003071
# 6                            0.000871                       0.023895
# 1                            0.006065                       0.041081
# 13                           0.000744                       0.012050
# 14                           0.000865                       0.025724
# 3                            0.002982                       0.002195
# 10                           0.000778                       0.018860
# 9                            0.004312                       0.005550
# 0                            0.002485                       0.012526
# 4                            0.001358                       0.005589

# %%
clf_col_prefix
# Out:
# ['bace_classification', 'bbbp', 'clintox', 'tox21']

# %%
clf_res_dfs = []
task = "77M-MTR"

for i in clf_col_prefix:
    val_sort_col = i+"_test_roc_auc_score_mean"
    sub_df = mtr_df[mtr_df.pretraining_task == task].sort_values(by=val_sort_col, ascending=False)
    test_mean_col = i+"_test_roc_auc_score_mean"
    test_std_col = i+"_test_roc_auc_score_std"
    sub_df = sub_df[[test_mean_col, test_std_col]]
    clf_res_dfs.append(sub_df.reset_index(drop=True))

# %%
clf_res_df = pd.concat(clf_res_dfs, axis=1)

# %%
clf_res_df
# Out:
#    bace_classification_test_roc_auc_score_mean  \
# 0                                     0.817065
# 1                                     0.811486
# 2                                     0.759058
# 3                                     0.718478
# 4                                     0.643768
#
#    bace_classification_test_roc_auc_score_std  bbbp_test_roc_auc_score_mean  \
# 0                                    0.004224                      0.724636
# 1                                    0.001359                      0.723538
# 2                                    0.000000                      0.722844
# 3                                    0.000000                      0.717738
# 4                                    0.000089                      0.677464
#
#    bbbp_test_roc_auc_score_std  clintox_test_roc_auc_score_mean  \
# 0                     0.001514                         0.770184
# 1                     0.001426                         0.736291
# 2                     0.001697                         0.653637
# 3                     0.002059                         0.608873
# 4                     0.001677                         0.521263
#
#    clintox_test_roc_auc_score_std  tox21_test_roc_auc_score_mean  \
# 0                        0.003883                       0.819531
# 1                        0.003736                       0.798219
# 2                        0.002878                       0.787348
# 3                        0.006343                       0.772504
# 4                        0.001196                       0.752992
#
#    tox21_test_roc_auc_score_std
# 0                      0.001457
# 1                      0.011476
# 2                      0.008803
# 3                      0.003099
# 4                      0.002091

# %%
mlm_df.filter(like='clearance')
# Out:
#     clearance_valid_pearsonr_mean  clearance_valid_rmse_mean  \
# 20                       0.436969                   1.162745
# 14                       0.418765                   1.170498
# 16                       0.424372                   1.176494
# 9                        0.427645                   1.165810
# 15                       0.377785                   1.218731
# 3                        0.329497                   1.228269
# 19                       0.328244                   1.221911
# 18                       0.425430                   1.168714
# 10                       0.284052                   1.238737
# 13                       0.103724                   1.285229
# 6                        0.220787                   1.254712
# 2                        0.401703                   1.180674
# 17                       0.199626                   1.267089
# 11                       0.334696                   1.215716
# 0                        0.199978                   1.269054
#
#     clearance_valid_pearsonr_std  clearance_valid_rmse_std  \
# 20                      0.004418                  0.002780
# 14                      0.003088                  0.001806
# 16                      0.025706                  0.013455
# 9                       0.004334                  0.003029
# 15                      0.023918                  0.007788
# 3                       0.013655                  0.006409
# 19                      0.009218                  0.007291
# 18                      0.027825                  0.019066
# 10                      0.065997                  0.020236
# 13                      0.009838                  0.001112
# 6                       0.075769                  0.017743
# 2                       0.016437                  0.009342
# 17                      0.008699                  0.001030
# 11                      0.051026                  0.022928
# 0                       0.013929                  0.003483
#
#     clearance_test_pearsonr_mean  clearance_test_rmse_mean  \
# 20                      0.484437                  1.088797
# 14                      0.484851                  1.085561
# 16                      0.443641                  1.129781
# 9                       0.467909                  1.098456
# 15                      0.408635                  1.170315
# 3                       0.446301                  1.151314
# 19                      0.479968                  1.095174
# 18                      0.486771                  1.090579
# 10                      0.454849                  1.136953
# 13                      0.284718                  1.228692
# 6                       0.420305                  1.158150
# 2                       0.367091                  1.157533
# 17                      0.306890                  1.200019
# 11                      0.309944                  1.184409
# 0                       0.327021                  1.200914
#
#     clearance_test_pearsonr_std  clearance_test_rmse_std
# 20                     0.005345                 0.003811
# 14                     0.003891                 0.002767
# 16                     0.041281                 0.019043
# 9                      0.001415                 0.001110
# 15                     0.044449                 0.012772
# 3                      0.010181                 0.012671
# 19                     0.011485                 0.006246
# 18                     0.008569                 0.010051
# 10                     0.054959                 0.036227
# 13                     0.023538                 0.003922
# 6                      0.072153                 0.036642
# 2                      0.026087                 0.015047
# 17                     0.012048                 0.004761
# 11                     0.047579                 0.018135
# 0                      0.024758                 0.004364

# %%
# just get the best overall for each task
regr_tasks = ['delaney', 'bace_regression', 'clearance', 'lipo']
clf_tasks = ['bbbp', 'bace_classification', 'clintox', 'tox21']
mm = {
    "roc_auc_score": "ROC AUC",
    "average_precision_score": "PR AUC",
}

# %%
mlm_df.filter(like='mean')
regr_df = pd.DataFrame()

for regr_task in regr_tasks:
    regr_df = regr_df.append(mlm_df)
# Out:
#   File "/tmp/ipykernel_3177/3928367725.py", line 4
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
metric='roc_auc_score'
task = 'tox21'
mlm_df.filter(like=f'{task}_test').sort_values(by=f'{task}_test_{metric}_mean', ascending=False)
# Out:
#     tox21_test_roc_auc_score_mean  tox21_test_average_precision_score_mean  \
# 9                        0.763433                                 0.344838
# 3                        0.763036                                 0.348931
# 13                       0.753726                                 0.345733
# 19                       0.745829                                 0.302185
# 10                       0.745301                                 0.298567
# 18                       0.745281                                 0.316157
# 0                        0.743784                                 0.264033
# 11                       0.740144                                 0.304292
# 14                       0.740105                                 0.357602
# 6                        0.737463                                 0.312435
# 17                       0.737179                                 0.275546
# 20                       0.735437                                 0.331569
# 16                       0.722692                                 0.324485
# 15                       0.721121                                 0.352393
# 2                        0.718362                                 0.309210
#
#     tox21_test_roc_auc_score_std  tox21_test_average_precision_score_std
# 9                       0.006190                                0.006467
# 3                       0.015341                                0.007947
# 13                      0.010551                                0.016043
# 19                      0.010798                                0.004848
# 10                      0.015782                                0.015021
# 18                      0.017602                                0.019095
# 0                       0.011447                                0.009164
# 11                      0.006138                                0.021326
# 14                      0.006108                                0.004955
# 6                       0.009331                                0.016000
# 17                      0.007113                                0.016156
# 20                      0.002723                                0.002399
# 16                      0.010164                                0.027839
# 15                      0.006249                                0.023872
# 2                       0.033522                                0.020414
